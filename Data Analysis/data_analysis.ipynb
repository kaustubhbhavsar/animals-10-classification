# %% [markdown]
# **AIM: To perform dataset analysis.**

# %%
# Note: Comment or delete the current code block if dataset is loaded from local disk.
# loading dataset from kaggle
# upload kaggle.json file
! pip install -q kaggle
from google.colab import files
print("Upload 'kaggle.json' file...")
files.upload()

# download the dataset(zipped folder) and unzip it
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets download alessiocorrado99/animals10
! unzip animals10.zip
# Out:
# Upload 'kaggle.json' file...
#      <input type="file" id="files-5960586c-18af-4101-94e7-d67655c6ab6c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5960586c-18af-4101-94e7-d67655c6ab6c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# import libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pathlib
import PIL
import os

# %% [markdown]
# Observations:
#
#
#
# 1.   Total 10 output classes namely: cane, cavallo, elefante, farfalla, gallina, gatto, mucca, pecora, ragno, scoiattolo.

# %%
# getting output class labels
class_labels = sorted(os.listdir('raw-img')) # get class labels
print('\nOutput Class Labels: {}'.format(class_labels))
# Out:
# Output Class Labels: ['cane', 'cavallo', 'elefante', 'farfalla', 'gallina', 'gatto', 'mucca', 'pecora', 'ragno', 'scoiattolo']

# %%
# getting number of output classes
num_classes = len(class_labels) 
print('\nNumber of Output Classes: {}'.format(num_classes))
# Out:
# Number of Output Classes: 10

# %% [markdown]
# Observations:
#
#
# 1.   There is class imbalance in the dataset.
# 2.   Cane and Ragno classes are highly dominating with 4863 and 4821 elements respectively.
# 3.   Elefante has lowest number of 1446 elements.

# %%
# calculating total elements in each class
class_totals = [len(os.listdir('raw-img' + f"/{label}")) for label in class_labels]
print("\nTotal Elements in Each Class : {}".format(class_totals))
# Out:
# Total Elements in Each Class : [4863, 2623, 1446, 2112, 3098, 1668, 1866, 1820, 4821, 1862]

# %%
# plotting class distribution
plt.figure(figsize=(10,5))
sns.barplot(x=class_labels, y=class_totals)
plt.title('Output Class Distribution')
plt.show()

# %% [markdown]
# **Plotting few Images**
#
# Observations:
#
#
# 1.   Images are of varying sizes.

# %%
# image data directory path
data_directory = pathlib.Path('raw-img')

# %%
# plotting 20th picture under 'elefante' class
elefante = list(data_directory.glob('elefante/*'))
PIL.Image.open(str(elefante[20]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x7F24C5B58B50>

# %%
# plotting 100th picture under 'mucca' class
mucca = list(data_directory.glob('mucca/*'))
PIL.Image.open(str(mucca[100]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x204 at 0x7F24D7EB0DF0>

# %%
# plotting 2340th picture under 'ragno' class
ragno = list(data_directory.glob('ragno/*'))
PIL.Image.open(str(ragno[2340]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x225 at 0x7F24C5520C40>

# %%
# plotting 4100th picture under 'cane' class
cane = list(data_directory.glob('cane/*'))
PIL.Image.open(str(cane[4100]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x7F24C5520640>

# %% [markdown]
# **Conclusion:**
#
#
# 1.   Total 10 output classes.
# 2.   Dataset is imbalanced.
# 3.   Images are of varying sizes.
